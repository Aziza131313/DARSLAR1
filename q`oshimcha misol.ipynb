# %% [markdown]
# # case 11

# %%
k1=input("boshlang`ich holati=")
k2=int(input("buyruq="))
if k1=='s':
    if k2==0:
        print("sharq")
    if k2==1:
        print("g`arb")
    if k2==2:
        print("janub")
if k1=='sh':
    if k2==0:
        print("janub")
    if k2==1:
        print("shimol")
    if k2==2:
        print("g`arb")
if k1=="j":
    if k2==0:
        print("g`arb")
    if k2==1:
        print("sharq")
    if k2==2:
        print("shimol")
if k1=="g`":                                                
    if k2==0:
        print("shimol")
    if k2==1:
        print("janub")
    if k2==2:
        print("sharq")
# Out:
# boshlang`ich holati=j
# buyruq=2
# shimol

# %% [markdown]
# #  1 dan milliongacha

# %%
a=int(input("a="))
      
millionlik=a//1000000
yuzminglik=a%1000000//100000
onminglik=a%100000//10000
minglik=a%10000//1000
yuzlik=a%1000//100
onlik=a%100//10
birlik=a%10


if millionlik==1:
    print("birmillion ",end='')
if millionlik==2:
    print("ikkimillion ",end='')
if millionlik==3:
    print("uchmillion ",end='')
if millionlik==4:
    print("to`rtmillion ",end='')
if millionlik==5:
    print("beshmillion ",end='')    
if millionlik==6:
    print("oltimillion ",end='')   
if millionlik==7:
    print("yettmillion ",end='')   
if millionlik==8:
    print("sakkizmillion ",end='')
if millionlik==9:
    print("to`qqizmillion ",end='')    

if yuzminglik==1:
    print("biryuzming ",end='')
if yuzminglik==2:
    print("ikkiyuzming ",end='')
if yuzminglik==3:
    print("uchyuzming ",end='')
if yuzminglik==4:
    print("to`rtyuzming ",end='')
if yuzminglik==5:
    print("beshyuzming ",end='')    
if yuzminglik==6:
    print("oltiyuzming ",end='')   
if yuzminglik==7:
    print("yettiyuzming ",end='')   
if yuzminglik==8:
    print("sakkizyuzming ",end='')
if yuzminglik==9:
    print("to`qqizyuzming ",end='')    

if onminglik==1:
    print("o`nming",end='')
if onminglik==2:
    print("yigirma",end='')
if onminglik==3:
    print("o`ttiz ",end='')
if onminglik==4:
    print("qirq ",end='')
if onminglik==5:
    print("ellik ",end='')    
if onminglik==6:
    print("oltmish  ",end='')   
if onminglik==7:
    print("yetmish ",end='')   
if onminglik==8:
    print("sakson ",end='')
if onminglik==9:
    print("to`qson ",end='')    

if minglik==1:
    print("ming ",end='')
if minglik==2:
    print("ikkiming ",end='')
if minglik==3:
    print("uchming ",end='')
if minglik==4:
    print("to`rtming ",end='')
if minglik==5:
    print("beshming ",end='')    
if minglik==6:
    print("oltiming ",end='')   
if minglik==7:
    print("yettiming ",end='')   
if minglik==8:
    print("sakkizming ",end='')
if minglik==9:
    print("to`qqizming ",end='')    
        

if yuzlik==1:
    print("biryuz ",end='')
if yuzlik==2:
    print("ikkiyuz ",end='')
if yuzlik==3:
    print("uch yuz ",end='')
if yuzlik==4:
    print("to`rtyuz ",end='')
if yuzlik==5:
    print("beshyuz ",end='')    
if yuzlik==6:
    print("oltiyuz ",end='')   
if yuzlik==7:
    print("yettiyuz ",end='')   
if yuzlik==8:
    print("sakkizyuz ",end='')
if yuzlik==9:
    print("to`qqizyuz ",end='')    
        
if onlik==1:
    print("o`n ",end='')
if onlik==2:
    print("yigirma ",end='')
if onlik==3:
    print("o`ttiz ",end='')
if onlik==4:
    print("qirq ",end='')  
if onlik==5:
    print("ellik ",end='')
if onlik==6:
    print("oltmish ",end='')
if onlik==7:
    print("yetmish ",end='')
if onlik==8:
    print("sakson ",end='')      
if onlik==9:                                       
    print("to`qson ",end='')

if birlik==1:                                  
    print("bir")
if birlik==2:
    print("ikki")
if birlik==3:
    print("uch")
if birlik==4:
    print("to`rt")
if birlik==5:
    print("besh")
if birlik==6:
    print("olti")
if birlik==7:
    print("yetti")
if birlik==8:
    print("sakkiz")
if birlik==9:
    print("to`qqiz")
# Out:
# a=4567891
# to`rtmillion beshyuzming oltmish  yettiming sakkizyuz to`qson bir

# %% [markdown]
# # keyingi kunni topish

# %%
d=int(input("d="))
m=int(input("m="))
yil=int(input("yil="))
if yil%4==0:
    kabisa = true
if yil%100==0 and yil%400!=0:
    kabisa = false
    
    d=d+1
if m==4 or m==6 or m==9 or m==11:
    if d>30:
        d=1
        m=m+1
elif m==2:
    if d>28 :
        d=1
        m=3
else:
    if d>31:
        d=1
        m=m+1
    if m>12:
        m=1
print(d,m,yil,sep='/')
# Out:
# d=5
# m=4
# yil=19997
# 5/4/19997
